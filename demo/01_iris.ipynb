# %% [markdown]
# # Demo 1 — Iris (multiclass classification)
#
# Classic flower dataset: 150 rows, 3 balanced species, 4 continuous measurements.
#
# **Goal:** predict `species` from the 4 measurements.
#
# Expected profile: multiclass classification, numeric features, small and clean dataset.
# Point the model-tree MCP (`analisar_dataset`) at `iris.csv` and check the recommendation.

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
print(df.shape)
df.head()

# %%
df.info()
df['species'].value_counts()

# %% [markdown]
# ## EDA
#
# _(exploratory analysis here)_
