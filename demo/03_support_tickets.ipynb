# %% [markdown]
# # Demo 3 — Support tickets (count target with excess zeros)
#
# 800 rows. **Count** target `support_tickets` per customer, with ~58% zeros and overdispersion.
# Includes missing values (`monthly_usage`, `tenure_months`) and a high-cardinality categorical (`city`, 20 values).
#
# **Goal:** predict how many tickets a customer will open.
#
# Expected profile: count target with excess zeros -> Poisson / Negative Binomial / Zero-Inflated / Hurdle family.
# Harder case: missing values + high cardinality. Point the model-tree MCP (`analisar_dataset`) at `support_tickets.csv`.

# %%
import pandas as pd

df = pd.read_csv('support_tickets.csv')
print(df.shape)
df.head()

# %%
df.info()
print('zeros:', (df['support_tickets'] == 0).mean())
df['support_tickets'].describe()

# %% [markdown]
# ## EDA
#
# _(exploratory analysis here)_
